# %% [markdown]
# <a href="https://colab.research.google.com/github/dapousman/ComputerVision2021/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Images/kitten.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Images/kitten.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# TASK 1

# %%
imgfig = img3
plt.figure(figsize=(3,6))
plt.imshow(imgfig)

# %% [markdown]
# TASK 2

# %%
#Red-Green Channel Only
RedGreen = cv.cvtColor(img, cv.COLOR_BGR2RGB)
RedGreen[:,:,2] = 0
plt.imshow(RedGreen)

# %%
#Green-Blue Channel Only
GreenBlue = cv.cvtColor(img, cv.COLOR_BGR2RGB)
GreenBlue[:,:,0] = 0
plt.imshow(GreenBlue)

# %% [markdown]
# TASK 3

# %%
#Show image row 10-100, column 10-100
ImageRowColumns = cv.cvtColor(img, cv.COLOR_BGR2RGB)
ImageRowColumns = ImageRowColumns[10:100, 10:100]
plt.imshow(ImageRowColumns)

# %% [markdown]
# TASK 4

# %%
#Show image row 5-30, all columns, Green channel only
GreenRow = cv.cvtColor(img, cv.COLOR_BGR2RGB)
GreenRow = GreenRow[5:30]
GreenRow[:,:,0] = 0
GreenRow[:,:,2] = 0
plt.imshow(GreenRow)

# %% [markdown]
# TASK 5

# %%
#5 boxes of different size and colors in one image
pic = cv.imread('/content/drive/MyDrive/Images/risitas.jpg')
pic = cv.cvtColor(pic, cv.COLOR_BGR2RGB)
cv.rectangle(pic, pt1=(0,0), pt2=(200,200), color=(255,255,255), thickness=10)
cv.rectangle(pic, pt1=(400,300), pt2=(600,400), color=(255,0,0), thickness=10)
cv.rectangle(pic, pt1=(400,500), pt2=(500,600), color=(0,255,0), thickness=10)
cv.rectangle(pic, pt1=(600,100), pt2=(800,200), color=(255,255,0), thickness=10)
cv.rectangle(pic, pt1=(800,400), pt2=(1000,700), color=(0,255,255), thickness=10)
plt.imshow(pic)

# %% [markdown]
# TASK 6

# %%
#Show the image upside-down
picUpsideDown = cv.flip(pic, 0)
plt.imshow(picUpsideDown)

# %% [markdown]
# TASK 7

# %%
#Make rectangles and circles on face
picTask = cv.imread('/content/drive/MyDrive/Images/bwah.jpg')
picTask = cv.cvtColor(picTask, cv.COLOR_BGR2RGB)
cv.rectangle(picTask, pt1=(170,100), pt2=(670,600), color=(0,0,255), thickness=30)
cv.circle(picTask, center=(2750, 350), radius=200, color=(255,0,0), thickness=30)
plt.imshow(picTask)

# %% [markdown]
# TASK 8

# %%
#Create a rectangle on lower left on Channel B
ImageRecB = cv.cvtColor(img, cv.COLOR_BGR2RGB)
height = ImageRecB.shape[0]
width = ImageRecB.shape[1]
ImageRecB[:,:,0] = 0
ImageRecB[:,:,1] = 0
cv.rectangle(ImageRecB, pt1=(0,height), pt2=(50,150), color=(255,255,255), thickness=5)
plt.imshow(ImageRecB)

# %% [markdown]
# TASK 9

# %%
#Complete the writing on black image
blackim = np.zeros(shape=(512,512,3),dtype=np.int16)
font = cv.FONT_HERSHEY_COMPLEX_SMALL
cv.putText(blackim,text='Daffa Usman',org=(10,250),fontFace=font,fontScale=2,color=(0,255,255),thickness=2,lineType=cv.LINE_AA)
plt.imshow(blackim)
